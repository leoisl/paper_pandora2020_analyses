# %%
import pandas as pd

# %%
# preprocessing
# !cp ../pandora1_paper_analysis_output_20_way/illumina_analysis/ROC_data.tsv ROC_data_illumina.tsv
# !cp ../pandora1_paper_analysis_output_20_way/illumina_analysis_with_filters/ROC_data.tsv ROC_data_illumina_filters.tsv
# !cp ../pandora1_paper_analysis_output_20_way/nanopore_analysis/ROC_data.tsv ROC_data_nanopore.tsv
# !cp ../pandora1_paper_analysis_output_20_way/nanopore_analysis_with_filters/ROC_data.tsv ROC_data_nanopore_filters.tsv

# %%
df_illumina = pd.read_csv("ROC_data_illumina.tsv", sep="\t")
df_illumina_filtered = pd.read_csv("ROC_data_illumina_filters.tsv", sep="\t")
df_nanopore = pd.read_csv("ROC_data_nanopore.tsv", sep="\t")
df_nanopore_filtered = pd.read_csv("ROC_data_nanopore_filters.tsv", sep="\t")

df = pd.concat([df_illumina, df_illumina_filtered, df_nanopore, df_nanopore_filtered], ignore_index=True).drop(columns=['Unnamed: 0'])
df
# Out:
#                              tool coverage  coverage_threshold  \
# 0             samtools_CP018206.1     100x                   0
# 1             samtools_CP018206.1     100x                   0
# 2             samtools_CP018206.1     100x                   0
# 3             samtools_CP018206.1     100x                   0
# 4             samtools_CP018206.1     100x                   0
# ...                           ...      ...                 ...
# 2195  pandora_nanopore_withdenovo     100x                   5
# 2196  pandora_nanopore_withdenovo     100x                   5
# 2197  pandora_nanopore_withdenovo     100x                   5
# 2198  pandora_nanopore_withdenovo     100x                   5
# 2199  pandora_nanopore_withdenovo     100x                   5
#
#      strand_bias_threshold gaps_threshold  step_GT  error_rate  \
# 0                  Not_App        Not_App        0    0.018076
# 1                  Not_App        Not_App        1    0.018004
# 2                  Not_App        Not_App        2    0.017395
# 3                  Not_App        Not_App        3    0.017281
# 4                  Not_App        Not_App        4    0.012606
# ...                    ...            ...      ...         ...
# 2195                  0.05            0.8        6    0.001683
# 2196                  0.05            0.8        7    0.001512
# 2197                  0.05            0.8        8    0.001316
# 2198                  0.05            0.8        9    0.001098
# 2199                  0.05            0.8       10    0.000865
#
#       nb_of_correct_calls  nb_of_total_calls  recalls_wrt_truth_probes  \
# 0            1.545163e+06          1573608.0                  0.914926
# 1            1.544548e+06          1572865.0                  0.914922
# 2            1.543466e+06          1570790.0                  0.914913
# 3            1.542926e+06          1570058.0                  0.914910
# 4            1.540116e+06          1559779.0                  0.914890
# ...                   ...                ...                       ...
# 2195         3.872988e+06          3879518.0                  0.895715
# 2196         3.809265e+06          3815032.0                  0.894685
# 2197         3.694726e+06          3699594.0                  0.893072
# 2198         3.478773e+06          3482596.0                  0.890482
# 2199         3.086043e+06          3088715.0                  0.886407
#
#       nbs_of_truth_probes_found  nbs_of_truth_probes_in_total  \
# 0                       6355266                       6946211
# 1                       6354953                       6945898
# 2                       6354245                       6945190
# 3                       6353971                       6944916
# 4                       6352330                       6943275
# ...                         ...                           ...
# 2195                    6115568                       6827579
# 2196                    6048776                       6760787
# 2197                    5946765                       6658776
# 2198                    5789316                       6501327
# 2199                    5556069                       6268080
#
#       recalls_wrt_variants_where_all_allele_seqs_were_found  \
# 0                                              0.781310
# 1                                              0.781142
# 2                                              0.780759
# 3                                              0.780557
# 4                                              0.779699
# ...                                                 ...
# 2195                                           0.747205
# 2196                                           0.730340
# 2197                                           0.701022
# 2198                                           0.652976
# 2199                                           0.569393
#
#       recalls_wrt_variants_found_wrt_alleles  \
# 0                                   0.796098
# 1                                   0.796015
# 2                                   0.795829
# 3                                   0.795750
# 4                                   0.795266
# ...                                      ...
# 2195                                0.833901
# 2196                                0.824383
# 2197                                0.810254
# 2198                                0.788764
# 2199                                0.757058
#
#       nbs_variants_where_all_allele_seqs_were_found  \
# 0                                            483088
# 1                                            482984
# 2                                            482747
# 3                                            482622
# 4                                            482090
# ...                                             ...
# 2195                                         461973
# 2196                                         451522
# 2197                                         433329
# 2198                                         403534
# 2199                                         351687
#
#       nbs_variants_found_wrt_alleles  nbs_variants_total
# 0                      492231.202509              618305
# 1                      492179.850988              618305
# 2                      492065.179763              618305
# 3                      492016.131703              618305
# 4                      491715.650742              618303
# ...                              ...                 ...
# 2195                   515574.390011              618268
# 2196                   509662.697934              618235
# 2197                   500849.564717              618139
# 2198                   487449.600987              617992
# 2199                   467599.157806              617653
#
# [2200 rows x 17 columns]

# %%
# filtering for step_GT == 0
df = df[df.step_GT == 0]
df
# Out:
#                              tool coverage  coverage_threshold  \
# 0             samtools_CP018206.1     100x                   0
# 11           samtools_NC_011993.1     100x                   0
# 22         samtools_NZ_HG941718.1     100x                   0
# 33         samtools_NZ_CP011134.1     100x                   0
# 44              snippy_CP010226.1     100x                   0
# ...                           ...      ...                 ...
# 2145         medaka_NZ_CP011134.1     100x                   5
# 2156            medaka_CU928163.2     100x                   5
# 2167           medaka_NC_011742.1     100x                   5
# 2178     nanopolish_NZ_CP016007.1     100x                   5
# 2189  pandora_nanopore_withdenovo     100x                   5
#
#      strand_bias_threshold gaps_threshold  step_GT  error_rate  \
# 0                  Not_App        Not_App        0    0.018076
# 11                 Not_App        Not_App        0    0.012916
# 22                 Not_App        Not_App        0    0.016617
# 33                 Not_App        Not_App        0    0.016496
# 44                 Not_App        Not_App        0    0.000118
# ...                    ...            ...      ...         ...
# 2145               Not_App        Not_App        0    0.181122
# 2156               Not_App        Not_App        0    0.184868
# 2167               Not_App        Not_App        0    0.189503
# 2178               Not_App        Not_App        0    0.028824
# 2189                  0.05            0.8        0    0.002051
#
#       nb_of_correct_calls  nb_of_total_calls  recalls_wrt_truth_probes  \
# 0            1.545163e+06          1573608.0                  0.914926
# 11           1.687889e+06          1709975.0                  0.872969
# 22           1.760691e+06          1790442.0                  0.892589
# 33           1.667790e+06          1695764.0                  0.912141
# 44           1.272479e+06          1272629.0                  0.856965
# ...                   ...                ...                       ...
# 2145         1.587093e+06          1938131.0                  0.903469
# 2156         1.674782e+06          2054616.0                  0.924069
# 2167         1.806233e+06          2228551.0                  0.908341
# 2178         1.668004e+06          1717509.0                  0.877454
# 2189         3.957803e+06          3965939.0                  0.897496
#
#       nbs_of_truth_probes_found  nbs_of_truth_probes_in_total  \
# 0                       6355266                       6946211
# 11                      6063829                       6946211
# 22                      6200112                       6946211
# 33                      6335927                       6946211
# 44                      5952660                       6946211
# ...                         ...                           ...
# 2145                    6275683                       6946211
# 2156                    6418781                       6946211
# 2167                    6309527                       6946211
# 2178                    6094983                       6946211
# 2189                    6234200                       6946211
#
#       recalls_wrt_variants_where_all_allele_seqs_were_found  \
# 0                                              0.781310
# 11                                             0.734980
# 22                                             0.771643
# 33                                             0.774917
# 44                                             0.700986
# ...                                                 ...
# 2145                                           0.798514
# 2156                                           0.815906
# 2167                                           0.803649
# 2178                                           0.750106
# 2189                                           0.773814
#
#       recalls_wrt_variants_found_wrt_alleles  \
# 0                                   0.796098
# 11                                  0.745423
# 22                                  0.786378
# 33                                  0.790875
# 44                                  0.715916
# ...                                      ...
# 2145                                0.794859
# 2156                                0.824059
# 2167                                0.812143
# 2178                                0.763619
# 2189                                0.851866
#
#       nbs_variants_where_all_allele_seqs_were_found  \
# 0                                            483088
# 11                                           454442
# 22                                           477111
# 33                                           479135
# 44                                           433423
# ...                                             ...
# 2145                                         493725
# 2156                                         504479
# 2167                                         496900
# 2178                                         463794
# 2189                                         478453
#
#       nbs_variants_found_wrt_alleles  nbs_variants_total
# 0                      492231.202509              618305
# 11                     460898.661681              618305
# 22                     486221.724861              618305
# 33                     489001.869009              618305
# 44                     442654.748854              618305
# ...                              ...                 ...
# 2145                   491465.426740              618305
# 2156                   509519.870807              618305
# 2167                   502152.075649              618305
# 2178                   472149.462960              618305
# 2189                   526712.811459              618305
#
# [200 rows x 17 columns]

# %%
# give a category for the tool
def get_tool_category(tool):
    if tool.startswith("pandora"):
        return tool.replace("_global_genotyping", "")
    else:
        return tool.split("_")[0]

df["tool_category"] = df["tool"].apply(get_tool_category)
df
# Out:
# <ipython-input-5-e5e8423e7027>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tool_category"] = df["tool"].apply(get_tool_category)
#                              tool coverage  coverage_threshold  \
# 0             samtools_CP018206.1     100x                   0
# 11           samtools_NC_011993.1     100x                   0
# 22         samtools_NZ_HG941718.1     100x                   0
# 33         samtools_NZ_CP011134.1     100x                   0
# 44              snippy_CP010226.1     100x                   0
# ...                           ...      ...                 ...
# 2145         medaka_NZ_CP011134.1     100x                   5
# 2156            medaka_CU928163.2     100x                   5
# 2167           medaka_NC_011742.1     100x                   5
# 2178     nanopolish_NZ_CP016007.1     100x                   5
# 2189  pandora_nanopore_withdenovo     100x                   5
#
#      strand_bias_threshold gaps_threshold  step_GT  error_rate  \
# 0                  Not_App        Not_App        0    0.018076
# 11                 Not_App        Not_App        0    0.012916
# 22                 Not_App        Not_App        0    0.016617
# 33                 Not_App        Not_App        0    0.016496
# 44                 Not_App        Not_App        0    0.000118
# ...                    ...            ...      ...         ...
# 2145               Not_App        Not_App        0    0.181122
# 2156               Not_App        Not_App        0    0.184868
# 2167               Not_App        Not_App        0    0.189503
# 2178               Not_App        Not_App        0    0.028824
# 2189                  0.05            0.8        0    0.002051
#
#       nb_of_correct_calls  nb_of_total_calls  recalls_wrt_truth_probes  \
# 0            1.545163e+06          1573608.0                  0.914926
# 11           1.687889e+06          1709975.0                  0.872969
# 22           1.760691e+06          1790442.0                  0.892589
# 33           1.667790e+06          1695764.0                  0.912141
# 44           1.272479e+06          1272629.0                  0.856965
# ...                   ...                ...                       ...
# 2145         1.587093e+06          1938131.0                  0.903469
# 2156         1.674782e+06          2054616.0                  0.924069
# 2167         1.806233e+06          2228551.0                  0.908341
# 2178         1.668004e+06          1717509.0                  0.877454
# 2189         3.957803e+06          3965939.0                  0.897496
#
#       nbs_of_truth_probes_found  nbs_of_truth_probes_in_total  \
# 0                       6355266                       6946211
# 11                      6063829                       6946211
# 22                      6200112                       6946211
# 33                      6335927                       6946211
# 44                      5952660                       6946211
# ...                         ...                           ...
# 2145                    6275683                       6946211
# 2156                    6418781                       6946211
# 2167                    6309527                       6946211
# 2178                    6094983                       6946211
# 2189                    6234200                       6946211
#
#       recalls_wrt_variants_where_all_allele_seqs_were_found  \
# 0                                              0.781310
# 11                                             0.734980
# 22                                             0.771643
# 33                                             0.774917
# 44                                             0.700986
# ...                                                 ...
# 2145                                           0.798514
# 2156                                           0.815906
# 2167                                           0.803649
# 2178                                           0.750106
# 2189                                           0.773814
#
#       recalls_wrt_variants_found_wrt_alleles  \
# 0                                   0.796098
# 11                                  0.745423
# 22                                  0.786378
# 33                                  0.790875
# 44                                  0.715916
# ...                                      ...
# 2145                                0.794859
# 2156                                0.824059
# 2167                                0.812143
# 2178                                0.763619
# 2189                                0.851866
#
#       nbs_variants_where_all_allele_seqs_were_found  \
# 0                                            483088
# 11                                           454442
# 22                                           477111
# 33                                           479135
# 44                                           433423
# ...                                             ...
# 2145                                         493725
# 2156                                         504479
# 2167                                         496900
# 2178                                         463794
# 2189                                         478453
#
#       nbs_variants_found_wrt_alleles  nbs_variants_total  \
# 0                      492231.202509              618305
# 11                     460898.661681              618305
# 22                     486221.724861              618305
# 33                     489001.869009              618305
# 44                     442654.748854              618305
# ...                              ...                 ...
# 2145                   491465.426740              618305
# 2156                   509519.870807              618305
# 2167                   502152.075649              618305
# 2178                   472149.462960              618305
# 2189                   526712.811459              618305
#
#                     tool_category
# 0                        samtools
# 11                       samtools
# 22                       samtools
# 33                       samtools
# 44                         snippy
# ...                           ...
# 2145                       medaka
# 2156                       medaka
# 2167                       medaka
# 2178                   nanopolish
# 2189  pandora_nanopore_withdenovo
#
# [200 rows x 18 columns]

# %%
# cleanup
df = df[["tool_category", "coverage_threshold", "strand_bias_threshold", "gaps_threshold", "error_rate", "recalls_wrt_variants_found_wrt_alleles", "tool"]]
df.to_csv("df_cleaned_up.csv", index=False)
df
# Out:
#                     tool_category  coverage_threshold strand_bias_threshold  \
# 0                        samtools                   0               Not_App
# 11                       samtools                   0               Not_App
# 22                       samtools                   0               Not_App
# 33                       samtools                   0               Not_App
# 44                         snippy                   0               Not_App
# ...                           ...                 ...                   ...
# 2145                       medaka                   5               Not_App
# 2156                       medaka                   5               Not_App
# 2167                       medaka                   5               Not_App
# 2178                   nanopolish                   5               Not_App
# 2189  pandora_nanopore_withdenovo                   5                  0.05
#
#      gaps_threshold  error_rate  recalls_wrt_variants_found_wrt_alleles  \
# 0           Not_App    0.018076                                0.796098
# 11          Not_App    0.012916                                0.745423
# 22          Not_App    0.016617                                0.786378
# 33          Not_App    0.016496                                0.790875
# 44          Not_App    0.000118                                0.715916
# ...             ...         ...                                     ...
# 2145        Not_App    0.181122                                0.794859
# 2156        Not_App    0.184868                                0.824059
# 2167        Not_App    0.189503                                0.812143
# 2178        Not_App    0.028824                                0.763619
# 2189            0.8    0.002051                                0.851866
#
#                              tool
# 0             samtools_CP018206.1
# 11           samtools_NC_011993.1
# 22         samtools_NZ_HG941718.1
# 33         samtools_NZ_CP011134.1
# 44              snippy_CP010226.1
# ...                           ...
# 2145         medaka_NZ_CP011134.1
# 2156            medaka_CU928163.2
# 2167           medaka_NC_011742.1
# 2178     nanopolish_NZ_CP016007.1
# 2189  pandora_nanopore_withdenovo
#
# [200 rows x 7 columns]

# %%
# get best precision results - rounded
df_best_precision = \
  df.sort_values(by=["error_rate"])\
  .groupby(by=["tool_category", "coverage_threshold", "strand_bias_threshold", "gaps_threshold"])\
  .head(1)\
  .sort_values(by=["tool_category"])
df_best_precision["error_rate"] = round(df_best_precision["error_rate"]*100, 3)
df_best_precision["recalls_wrt_variants_found_wrt_alleles"] = round(df_best_precision["recalls_wrt_variants_found_wrt_alleles"]*100, 1)
df_best_precision.to_csv("df_best_precision.rounded.csv", index=False)
df_best_precision
# Out:
#                     tool_category  coverage_threshold strand_bias_threshold  \
# 1903                       medaka                   5               Not_App
# 1353                       medaka                   0               Not_App
# 1848                   nanopolish                   5               Not_App
# 1111                   nanopolish                   0               Not_App
# 924     pandora_illumina_nodenovo                   5                  0.05
# 539     pandora_illumina_nodenovo                   0                   0.0
# 1001  pandora_illumina_withdenovo                   5                  0.05
# 352   pandora_illumina_withdenovo                   0                   0.0
# 1705    pandora_nanopore_nodenovo                   5                  0.05
# 1551    pandora_nanopore_nodenovo                   0                   0.0
# 2189  pandora_nanopore_withdenovo                   5                  0.05
# 1287  pandora_nanopore_withdenovo                   0                   0.0
# 572                      samtools                   5               Not_App
# 286                      samtools                   0               Not_App
# 627                        snippy                   5               Not_App
# 275                        snippy                   0               Not_App
#
#      gaps_threshold  error_rate  recalls_wrt_variants_found_wrt_alleles  \
# 1903        Not_App      14.767                                    74.9
# 1353        Not_App      14.767                                    74.9
# 1848        Not_App       2.408                                    73.9
# 1111        Not_App       2.408                                    73.9
# 924             0.8       0.127                                    84.8
# 539             1.0       0.157                                    85.0
# 1001            0.8       0.121                                    85.6
# 352             1.0       0.150                                    85.8
# 1705            0.8       0.136                                    84.7
# 1551            1.0       0.187                                    84.9
# 2189            0.8       0.205                                    85.2
# 1287            1.0       0.292                                    85.5
# 572         Not_App       0.576                                    73.2
# 286         Not_App       1.045                                    73.3
# 627         Not_App       0.010                                    73.7
# 275         Not_App       0.010                                    73.7
#
#                              tool
# 1903         medaka_NZ_LM995446.1
# 1353         medaka_NZ_LM995446.1
# 1848       nanopolish_NC_007779.1
# 1111       nanopolish_NC_007779.1
# 924     pandora_illumina_nodenovo
# 539     pandora_illumina_nodenovo
# 1001  pandora_illumina_withdenovo
# 352   pandora_illumina_withdenovo
# 1705    pandora_nanopore_nodenovo
# 1551    pandora_nanopore_nodenovo
# 2189  pandora_nanopore_withdenovo
# 1287  pandora_nanopore_withdenovo
# 572        samtools_NZ_LM995446.1
# 286        samtools_NZ_LM995446.1
# 627             snippy_CP010170.1
# 275             snippy_CP010170.1

# %%
# get best AvgAR results - rounded
df_best_recall = \
  df.sort_values(by=["recalls_wrt_variants_found_wrt_alleles"], ascending=False)\
  .groupby(by=["tool_category", "coverage_threshold", "strand_bias_threshold", "gaps_threshold"])\
  .head(1)\
  .sort_values(by=["tool_category"])
df_best_recall["error_rate"] = round(df_best_recall["error_rate"]*100, 2)
df_best_recall["recalls_wrt_variants_found_wrt_alleles"] = round(df_best_recall["recalls_wrt_variants_found_wrt_alleles"]*100, 1)
df_best_recall.to_csv("df_best_recall.rounded.csv", index=False)
df_best_recall
# Out:
#                     tool_category  coverage_threshold strand_bias_threshold  \
# 1232                       medaka                   0               Not_App
# 1760                       medaka                   5               Not_App
# 1496                   nanopolish                   0               Not_App
# 2013                   nanopolish                   5               Not_App
# 539     pandora_illumina_nodenovo                   0                   0.0
# 924     pandora_illumina_nodenovo                   5                  0.05
# 352   pandora_illumina_withdenovo                   0                   0.0
# 1001  pandora_illumina_withdenovo                   5                  0.05
# 1551    pandora_nanopore_nodenovo                   0                   0.0
# 1705    pandora_nanopore_nodenovo                   5                  0.05
# 1287  pandora_nanopore_withdenovo                   0                   0.0
# 2189  pandora_nanopore_withdenovo                   5                  0.05
# 176                      samtools                   0               Not_App
# 1078                     samtools                   5               Not_App
# 231                        snippy                   0               Not_App
# 682                        snippy                   5               Not_App
#
#      gaps_threshold  error_rate  recalls_wrt_variants_found_wrt_alleles  \
# 1232        Not_App       19.52                                    84.4
# 1760        Not_App       19.52                                    84.4
# 1496        Not_App        3.27                                    81.8
# 2013        Not_App        3.27                                    81.8
# 539             1.0        0.16                                    85.0
# 924             0.8        0.13                                    84.8
# 352             1.0        0.15                                    85.8
# 1001            0.8        0.12                                    85.6
# 1551            1.0        0.19                                    84.9
# 1705            0.8        0.14                                    84.7
# 1287            1.0        0.29                                    85.5
# 2189            0.8        0.21                                    85.2
# 176         Not_App        1.84                                    82.2
# 1078        Not_App        1.01                                    82.0
# 231         Not_App        0.04                                    81.1
# 682         Not_App        0.04                                    81.1
#
#                              tool
# 1232         medaka_NZ_CP009859.1
# 1760         medaka_NZ_CP009859.1
# 1496     nanopolish_NZ_CP009859.1
# 2013     nanopolish_NZ_CP009859.1
# 539     pandora_illumina_nodenovo
# 924     pandora_illumina_nodenovo
# 352   pandora_illumina_withdenovo
# 1001  pandora_illumina_withdenovo
# 1551    pandora_nanopore_nodenovo
# 1705    pandora_nanopore_nodenovo
# 1287  pandora_nanopore_withdenovo
# 2189  pandora_nanopore_withdenovo
# 176        samtools_NZ_CP009859.1
# 1078       samtools_NZ_CP009859.1
# 231          snippy_NZ_CP009859.1
# 682          snippy_NZ_CP009859.1
