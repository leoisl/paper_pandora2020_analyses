# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data reading

# %%
df_illumina = pd.read_csv("../df_illumina.R_data.csv")
df_illumina
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_illumina_withdenovo  pandora with denovo                  2
# 1             snippy_NC_011993.1               snippy                  2
# 2             snippy_NC_022648.1               snippy                  2
# 3              snippy_CP010121.1               snippy                  2
# 4           snippy_NZ_LM995446.1               snippy                  2
# ..                           ...                  ...                ...
# 926       samtools_NZ_CP016007.1             samtools                 20
# 927       samtools_NZ_CP013483.1             samtools                 20
# 928          samtools_CP010116.1             samtools                 20
# 929          samtools_CP010226.1             samtools                 20
# 930          samtools_CP010170.1             samtools                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               30647.0    0.483765      0.670439
# 1               19445.0    0.306941      0.349300
# 2               21229.0    0.335101      0.413537
# 3               18914.0    0.298559      0.355685
# 4               15115.0    0.238591      0.278512
# ..                  ...         ...           ...
# 926             10137.0    0.998227      0.997937
# 927             10123.0    0.996849      0.996470
# 928              9865.0    0.971443      0.971251
# 929             10013.0    0.986017      0.985810
# 930             10134.0    0.997932      0.997937
#
# [931 rows x 6 columns]

# %%
df_nanopore = pd.read_csv("../df_nanopore.R_data.csv")
df_nanopore
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_nanopore_withdenovo  pandora with denovo                  2
# 1             medaka_NC_011993.1               medaka                  2
# 2             medaka_NC_022648.1               medaka                  2
# 3              medaka_CP010121.1               medaka                  2
# 4           medaka_NZ_LM995446.1               medaka                  2
# ..                           ...                  ...                ...
# 926     nanopolish_NZ_CP016007.1           nanopolish                 20
# 927     nanopolish_NZ_CP013483.1           nanopolish                 20
# 928        nanopolish_CP010116.1           nanopolish                 20
# 929        nanopolish_CP010226.1           nanopolish                 20
# 930        nanopolish_CP010170.1           nanopolish                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               31054.0    0.490190      0.671789
# 1               22573.0    0.356316      0.394351
# 2               25630.0    0.404571      0.470119
# 3               23017.0    0.363325      0.410538
# 4               17542.0    0.276902      0.314518
# ..                  ...         ...           ...
# 926             10122.0    0.996750      0.995815
# 927             10093.0    0.993895      0.995047
# 928              9847.0    0.969670      0.970044
# 929              9982.0    0.982964      0.984003
# 930             10108.0    0.995372      0.996356
#
# [931 rows x 6 columns]

# %% [markdown]
# # Restricting to rare genes

# %%
df_illumina_rare_genes = df_illumina[df_illumina.NUMBER_OF_SAMPLES <= 5]
df_illumina_rare_genes
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_illumina_withdenovo  pandora with denovo                  2
# 1             snippy_NC_011993.1               snippy                  2
# 2             snippy_NC_022648.1               snippy                  2
# 3              snippy_CP010121.1               snippy                  2
# 4           snippy_NZ_LM995446.1               snippy                  2
# ..                           ...                  ...                ...
# 191       samtools_NZ_CP016007.1             samtools                  5
# 192       samtools_NZ_CP013483.1             samtools                  5
# 193          samtools_CP010116.1             samtools                  5
# 194          samtools_CP010226.1             samtools                  5
# 195          samtools_CP010170.1             samtools                  5
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               30647.0    0.483765      0.670439
# 1               19445.0    0.306941      0.349300
# 2               21229.0    0.335101      0.413537
# 3               18914.0    0.298559      0.355685
# 4               15115.0    0.238591      0.278512
# ..                  ...         ...           ...
# 191             11029.0    0.453290      0.484033
# 192              9325.0    0.383256      0.418980
# 193             10236.0    0.420698      0.456405
# 194              9082.0    0.373269      0.397016
# 195              9613.0    0.395093      0.416670
#
# [196 rows x 6 columns]

# %%
df_nanopore_rare_genes = df_nanopore[df_nanopore.NUMBER_OF_SAMPLES <= 5]
df_nanopore_rare_genes
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_nanopore_withdenovo  pandora with denovo                  2
# 1             medaka_NC_011993.1               medaka                  2
# 2             medaka_NC_022648.1               medaka                  2
# 3              medaka_CP010121.1               medaka                  2
# 4           medaka_NZ_LM995446.1               medaka                  2
# ..                           ...                  ...                ...
# 191     nanopolish_NZ_CP016007.1           nanopolish                  5
# 192     nanopolish_NZ_CP013483.1           nanopolish                  5
# 193        nanopolish_CP010116.1           nanopolish                  5
# 194        nanopolish_CP010226.1           nanopolish                  5
# 195        nanopolish_CP010170.1           nanopolish                  5
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               31054.0    0.490190      0.671789
# 1               22573.0    0.356316      0.394351
# 2               25630.0    0.404571      0.470119
# 3               23017.0    0.363325      0.410538
# 4               17542.0    0.276902      0.314518
# ..                  ...         ...           ...
# 191             10961.0    0.450495      0.480243
# 192              9123.0    0.374954      0.414533
# 193             10135.0    0.416547      0.452789
# 194              8758.0    0.359952      0.391550
# 195              9371.0    0.385147      0.412725
#
# [196 rows x 6 columns]

# %% [markdown]
# # Summing the number of found panvars

# %%
df_illumina_rare_genes_panvars_summed = \
    df_illumina_rare_genes.groupby(by=["tool_long_description", "tool"])\
    .agg({"nb_of_found_PanVar": np.sum})\
    .reset_index()
df_illumina_rare_genes_panvars_summed
# Out:
#           tool_long_description                 tool  nb_of_found_PanVar
# 0   pandora_illumina_withdenovo  pandora with denovo             89316.0
# 1           samtools_CP010116.1             samtools             56302.0
# 2           samtools_CP010121.1             samtools             60403.0
# 3           samtools_CP010170.1             samtools             52427.0
# 4           samtools_CP010171.1             samtools             55935.0
# 5           samtools_CP010226.1             samtools             49147.0
# 6           samtools_CP010230.1             samtools             53904.0
# 7           samtools_CP018206.1             samtools             62174.0
# 8           samtools_CU928163.2             samtools             69486.0
# 9          samtools_NC_007779.1             samtools             50258.0
# 10         samtools_NC_010498.1             samtools             69387.0
# 11         samtools_NC_011742.1             samtools             71606.0
# 12         samtools_NC_011993.1             samtools             59515.0
# 13         samtools_NC_017646.1             samtools             69371.0
# 14         samtools_NC_022648.1             samtools             71180.0
# 15       samtools_NZ_CP008697.1             samtools             66368.0
# 16       samtools_NZ_CP009859.1             samtools             71864.0
# 17       samtools_NZ_CP011134.1             samtools             60073.0
# 18       samtools_NZ_CP013483.1             samtools             53682.0
# 19       samtools_NZ_CP015228.1             samtools             61794.0
# 20       samtools_NZ_CP016007.1             samtools             69157.0
# 21       samtools_NZ_CP018109.1             samtools             55304.0
# 22       samtools_NZ_HG941718.1             samtools             71728.0
# 23       samtools_NZ_LM995446.1             samtools             49085.0
# 24       samtools_NZ_LT632320.1             samtools             71135.0
# 25            snippy_CP010116.1               snippy             50105.0
# 26            snippy_CP010121.1               snippy             54648.0
# 27            snippy_CP010170.1               snippy             48399.0
# 28            snippy_CP010171.1               snippy             51970.0
# 29            snippy_CP010226.1               snippy             45098.0
# 30            snippy_CP010230.1               snippy             49799.0
# 31            snippy_CP018206.1               snippy             54763.0
# 32            snippy_CU928163.2               snippy             62915.0
# 33           snippy_NC_007779.1               snippy             46589.0
# 34           snippy_NC_010498.1               snippy             63411.0
# 35           snippy_NC_011742.1               snippy             64723.0
# 36           snippy_NC_011993.1               snippy             55760.0
# 37           snippy_NC_017646.1               snippy             63467.0
# 38           snippy_NC_022648.1               snippy             64295.0
# 39         snippy_NZ_CP008697.1               snippy             60247.0
# 40         snippy_NZ_CP009859.1               snippy             63947.0
# 41         snippy_NZ_CP011134.1               snippy             53023.0
# 42         snippy_NZ_CP013483.1               snippy             48892.0
# 43         snippy_NZ_CP015228.1               snippy             54548.0
# 44         snippy_NZ_CP016007.1               snippy             64834.0
# 45         snippy_NZ_CP018109.1               snippy             49694.0
# 46         snippy_NZ_HG941718.1               snippy             64810.0
# 47         snippy_NZ_LM995446.1               snippy             45614.0
# 48         snippy_NZ_LT632320.1               snippy             64023.0

# %%
df_nanopore_rare_genes_panvars_summed = \
    df_nanopore_rare_genes.groupby(by=["tool_long_description", "tool"])\
    .agg({"nb_of_found_PanVar": np.sum})\
    .reset_index()
df_nanopore_rare_genes_panvars_summed
# Out:
#           tool_long_description                 tool  nb_of_found_PanVar
# 0             medaka_CP010116.1               medaka             62891.0
# 1             medaka_CP010121.1               medaka             67066.0
# 2             medaka_CP010170.1               medaka             57239.0
# 3             medaka_CP010171.1               medaka             60993.0
# 4             medaka_CP010226.1               medaka             54464.0
# 5             medaka_CP010230.1               medaka             60329.0
# 6             medaka_CP018206.1               medaka             68781.0
# 7             medaka_CU928163.2               medaka             76256.0
# 8            medaka_NC_007779.1               medaka             54434.0
# 9            medaka_NC_010498.1               medaka             75183.0
# 10           medaka_NC_011742.1               medaka             78312.0
# 11           medaka_NC_011993.1               medaka             65367.0
# 12           medaka_NC_017646.1               medaka             75632.0
# 13           medaka_NC_022648.1               medaka             77097.0
# 14         medaka_NZ_CP008697.1               medaka             72912.0
# 15         medaka_NZ_CP009859.1               medaka             78910.0
# 16         medaka_NZ_CP011134.1               medaka             65394.0
# 17         medaka_NZ_CP013483.1               medaka             59356.0
# 18         medaka_NZ_CP015228.1               medaka             68126.0
# 19         medaka_NZ_CP016007.1               medaka             75288.0
# 20         medaka_NZ_CP018109.1               medaka             61815.0
# 21         medaka_NZ_HG941718.1               medaka             77243.0
# 22         medaka_NZ_LM995446.1               medaka             53141.0
# 23         medaka_NZ_LT632320.1               medaka             77050.0
# 24        nanopolish_CP010116.1           nanopolish             55060.0
# 25        nanopolish_CP010121.1           nanopolish             59070.0
# 26        nanopolish_CP010170.1           nanopolish             51032.0
# 27        nanopolish_CP010171.1           nanopolish             54535.0
# 28        nanopolish_CP010226.1           nanopolish             47722.0
# 29        nanopolish_CP010230.1           nanopolish             53704.0
# 30        nanopolish_CP018206.1           nanopolish             59865.0
# 31        nanopolish_CU928163.2           nanopolish             67482.0
# 32       nanopolish_NC_007779.1           nanopolish             49106.0
# 33       nanopolish_NC_010498.1           nanopolish             66622.0
# 34       nanopolish_NC_011742.1           nanopolish             69689.0
# 35       nanopolish_NC_011993.1           nanopolish             58595.0
# 36       nanopolish_NC_017646.1           nanopolish             66516.0
# 37       nanopolish_NC_022648.1           nanopolish             68469.0
# 38     nanopolish_NZ_CP008697.1           nanopolish             64427.0
# 39     nanopolish_NZ_CP009859.1           nanopolish             69084.0
# 40     nanopolish_NZ_CP011134.1           nanopolish             57796.0
# 41     nanopolish_NZ_CP013483.1           nanopolish             52416.0
# 42     nanopolish_NZ_CP015228.1           nanopolish             59722.0
# 43     nanopolish_NZ_CP016007.1           nanopolish             68199.0
# 44     nanopolish_NZ_CP018109.1           nanopolish             53352.0
# 45     nanopolish_NZ_HG941718.1           nanopolish             69483.0
# 46     nanopolish_NZ_LM995446.1           nanopolish             48051.0
# 47     nanopolish_NZ_LT632320.1           nanopolish             69140.0
# 48  pandora_nanopore_withdenovo  pandora with denovo             90579.0

# %% [markdown]
# # Select the best values for each tool

# %%
df_illumina_best_values = \
    df_illumina_rare_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).first()\
    .reset_index()
df_illumina_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar
# 0  pandora with denovo  pandora_illumina_withdenovo             89316.0
# 1             samtools       samtools_NZ_CP009859.1             71864.0
# 2               snippy         snippy_NZ_CP016007.1             64834.0

# %%
df_nanopore_best_values = \
    df_nanopore_rare_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).first()\
    .reset_index()
df_nanopore_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar
# 0               medaka         medaka_NZ_CP009859.1             78910.0
# 1           nanopolish       nanopolish_NC_011742.1             69689.0
# 2  pandora with denovo  pandora_nanopore_withdenovo             90579.0

# %% [markdown]
# # Select the median values for each tool

# %%
df_illumina_median_values = \
    df_illumina_rare_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).median()\
    .reset_index()
df_illumina_median_values
# Out:
#                   tool  nb_of_found_PanVar
# 0  pandora with denovo             89316.0
# 1             samtools             61098.5
# 2               snippy             54705.5

# %%
df_nanopore_median_values = \
    df_nanopore_rare_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).median()\
    .reset_index()
df_nanopore_median_values
# Out:
#                   tool  nb_of_found_PanVar
# 0               medaka             67596.0
# 1           nanopolish             59396.0
# 2  pandora with denovo             90579.0

# %% [markdown]
# # Get how many panvars we have in total in rare genes, to be able to compute the recall

# %%
pangenome_variations_per_nb_of_samples = pd.read_csv("../../pandora1_paper_analysis_output_20_way/technology_independent_analysis/pangenome_variants_vs_samples/pangenome_variations_per_nb_of_samples.csv")
pangenome_variations_per_nb_of_samples
# Out:
#           PVID  NUMBER_OF_SAMPLES
# 0            0                  2
# 1            1                  4
# 2            2                  2
# 3            3                 20
# 4            4                 19
# ...        ...                ...
# 618300  681407                  2
# 618301  681408                  2
# 618302  681409                  2
# 618303  681410                  2
# 618304  681411                  2
#
# [618305 rows x 2 columns]

# %%
pangenome_variations_per_nb_of_samples_in_rare_genes = pangenome_variations_per_nb_of_samples[pangenome_variations_per_nb_of_samples.NUMBER_OF_SAMPLES <= 5]
pangenome_variations_per_nb_of_samples_in_rare_genes
# Out:
#           PVID  NUMBER_OF_SAMPLES
# 0            0                  2
# 1            1                  4
# 2            2                  2
# 10          10                  2
# 12          12                  2
# ...        ...                ...
# 618300  681407                  2
# 618301  681408                  2
# 618302  681409                  2
# 618303  681410                  2
# 618304  681411                  2
#
# [160197 rows x 2 columns]

# %%
number_of_panvars_in_rare_genes = len(pangenome_variations_per_nb_of_samples_in_rare_genes)
display(number_of_panvars_in_rare_genes)
# Out:
# 160197

# %% [markdown]
# # Compute recall

# %%
df_illumina_best_values["recall"] = df_illumina_best_values["nb_of_found_PanVar"] / number_of_panvars_in_rare_genes
df_illumina_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar  \
# 0  pandora with denovo  pandora_illumina_withdenovo             89316.0
# 1             samtools       samtools_NZ_CP009859.1             71864.0
# 2               snippy         snippy_NZ_CP016007.1             64834.0
#
#      recall
# 0  0.557539
# 1  0.448598
# 2  0.404714

# %%
df_illumina_median_values["recall"] = df_illumina_median_values["nb_of_found_PanVar"] / number_of_panvars_in_rare_genes
df_illumina_median_values
# Out:
#                   tool  nb_of_found_PanVar    recall
# 0  pandora with denovo             89316.0  0.557539
# 1             samtools             61098.5  0.381396
# 2               snippy             54705.5  0.341489

# %%
df_nanopore_best_values["recall"] = df_nanopore_best_values["nb_of_found_PanVar"] / number_of_panvars_in_rare_genes
df_nanopore_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar  \
# 0               medaka         medaka_NZ_CP009859.1             78910.0
# 1           nanopolish       nanopolish_NC_011742.1             69689.0
# 2  pandora with denovo  pandora_nanopore_withdenovo             90579.0
#
#      recall
# 0  0.492581
# 1  0.435021
# 2  0.565423

# %%
df_nanopore_median_values["recall"] = df_nanopore_median_values["nb_of_found_PanVar"] / number_of_panvars_in_rare_genes
df_nanopore_median_values
# Out:
#                   tool  nb_of_found_PanVar    recall
# 0               medaka             67596.0  0.421955
# 1           nanopolish             59396.0  0.370768
# 2  pandora with denovo             90579.0  0.565423

# %% [markdown]
# # Create report

# %%
def extract_value(df, queried_tool, column):
    return df[df.tool==queried_tool][column].to_list()[0]

from collections import defaultdict
tech_to_tool_to_measure = defaultdict(lambda: defaultdict(lambda: defaultdict(float)))

for measure in ["nb_of_found_PanVar", "recall"]:
    tech_to_tool_to_measure["illumina"]["pandora with denovo"][measure] = extract_value(df_illumina_best_values, "pandora with denovo", measure)
    for tool in ["samtools", "snippy"]:
        tech_to_tool_to_measure["illumina"][tool+"_best"][measure] = extract_value(df_illumina_best_values, tool, measure)
        tech_to_tool_to_measure["illumina"][tool+"_median"][measure] = extract_value(df_illumina_median_values, tool, measure)

    tech_to_tool_to_measure["nanopore"]["pandora with denovo"][measure] = extract_value(df_nanopore_best_values, "pandora with denovo", measure)
    for tool in ["medaka", "nanopolish"]:
        tech_to_tool_to_measure["nanopore"][tool+"_best"][measure] = extract_value(df_nanopore_best_values, tool, measure)
        tech_to_tool_to_measure["nanopore"][tool+"_median"][measure] = extract_value(df_nanopore_median_values, tool, measure)

tech_to_tool_to_measure
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'illumina': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pandora with denovo': defaultdict(float,
#                                       {'nb_of_found_PanVar': 89316.0,
#                                        'recall': 0.5575385306840952}),
#                           'samtools_best': defaultdict(float,
#                                       {'nb_of_found_PanVar': 71864.0,
#                                        'recall': 0.4485976641260448}),
#                           'samtools_median': defaultdict(float,
#                                       {'nb_of_found_PanVar': 61098.5,
#                                        'recall': 0.381396031136663}),
#                           'snippy_best': defaultdict(float,
#                                       {'nb_of_found_PanVar': 64834.0,
#                                        'recall': 0.4047141956466101}),
#                           'snippy_median': defaultdict(float,
#                                       {'nb_of_found_PanVar': 54705.5,
#                                        'recall': 0.34148891677122545})}),
#              'nanopore': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pandora with denovo': defaultdict(float,
#                                       {'nb_of_found_PanVar': 90579.0,
#                                        'recall': 0.5654225734564318}),
#                           'medaka_best': defaultdict(float,
#                                       {'nb_of_found_PanVar': 78910.0,
#                                        'recall': 0.4925810096318907}),
#                           'medaka_median': defaultdict(float,
#                                       {'nb_of_found_PanVar': 67596.0,
#                                        'recall': 0.4219554673308489}),
#                           'nanopolish_best': defaultdict(float,
#                                       {'nb_of_found_PanVar': 69689.0,
#                                        'recall': 0.4350206308482681}),
#                           'nanopolish_median': defaultdict(float,
#                                       {'nb_of_found_PanVar': 59396.0,
#                                        'recall': 0.37076849129509293})})})

# %%
from statistics import mean

all_recalls = {"best": [], "median": []}
for technology in ["illumina", "nanopore"]:
    print(f"For {technology}:")
    recalls = {"best": [], "median": []}
    for method in ["best", "median"]:
        print(f"  * Considering {method} points:")
        if technology == "illumina":
            tools = ["samtools", "snippy"]
        else:
            tools = ["medaka", "nanopolish"]
        
        for tool in tools:
            # print(f"Pandora identified {int(tech_to_tool_to_measure['illumina']['pandora with denovo']['nb_of_found_PanVar'] - tech_to_tool_to_measure['illumina'][f'{tool}_{method}']['nb_of_found_PanVar'])} more pan vars than {tool}_{method}")
            recall_delta = round((tech_to_tool_to_measure[technology]['pandora with denovo']['recall'] - tech_to_tool_to_measure[technology][f'{tool}_{method}']['recall'])*100, 1)
            recalls[method].append(recall_delta)
            all_recalls[method].append(recall_delta)
            print(f"    * Pandora had a recall {recall_delta}% higher than {tool}_{method}")
    print(f"Summary for {technology}:")
    for method in ["best", "median"]:
        print(f"  * Considering {method} points: Pandora had on average a recall {round(mean(recalls[method]), 1)}% higher than the other tools")
    print("\n")

print(f"Global summary:")
for method in ["best", "median"]:
    print(f"  * Considering {method} points: Pandora had on average a recall {round(mean(all_recalls[method]), 1)}% higher than the other tools")
# Out:
# For illumina:
#   * Considering best points:
#     * Pandora had a recall 10.9% higher than samtools_best
#     * Pandora had a recall 15.3% higher than snippy_best
#   * Considering median points:
#     * Pandora had a recall 17.6% higher than samtools_median
#     * Pandora had a recall 21.6% higher than snippy_median
# Summary for illumina:
#   * Considering best points: Pandora had on average a recall 13.1% higher than the other tools
#   * Considering median points: Pandora had on average a recall 19.6% higher than the other tools
#
#
# For nanopore:
#   * Considering best points:
#     * Pandora had a recall 7.3% higher than medaka_best
#     * Pandora had a recall 13.0% higher than nanopolish_best
#   * Considering median points:
#     * Pandora had a recall 14.3% higher than medaka_median
#     * Pandora had a recall 19.5% higher than nanopolish_median
# Summary for nanopore:
#   * Considering best points: Pandora had on average a recall 10.2% higher than the other tools
#   * Considering median points: Pandora had on average a recall 16.9% higher than the other tools
#
#
# Global summary:
#   * Considering best points: Pandora had on average a recall 11.6% higher than the other tools
#   * Considering median points: Pandora had on average a recall 18.2% higher than the other tools
