# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data reading

# %%
df_illumina = pd.read_csv("../df_illumina.R_data.csv")
df_illumina
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_illumina_withdenovo  pandora with denovo                  2
# 1             snippy_NC_011993.1               snippy                  2
# 2             snippy_NC_022648.1               snippy                  2
# 3              snippy_CP010121.1               snippy                  2
# 4           snippy_NZ_LM995446.1               snippy                  2
# ..                           ...                  ...                ...
# 926       samtools_NZ_CP016007.1             samtools                 20
# 927       samtools_NZ_CP013483.1             samtools                 20
# 928          samtools_CP010116.1             samtools                 20
# 929          samtools_CP010226.1             samtools                 20
# 930          samtools_CP010170.1             samtools                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               30647.0    0.483765      0.670439
# 1               19445.0    0.306941      0.349300
# 2               21229.0    0.335101      0.413537
# 3               18914.0    0.298559      0.355685
# 4               15115.0    0.238591      0.278512
# ..                  ...         ...           ...
# 926             10137.0    0.998227      0.997937
# 927             10123.0    0.996849      0.996470
# 928              9865.0    0.971443      0.971251
# 929             10013.0    0.986017      0.985810
# 930             10134.0    0.997932      0.997937
#
# [931 rows x 6 columns]

# %%
df_nanopore = pd.read_csv("../df_nanopore.R_data.csv")
df_nanopore
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 0    pandora_nanopore_withdenovo  pandora with denovo                  2
# 1             medaka_NC_011993.1               medaka                  2
# 2             medaka_NC_022648.1               medaka                  2
# 3              medaka_CP010121.1               medaka                  2
# 4           medaka_NZ_LM995446.1               medaka                  2
# ..                           ...                  ...                ...
# 926     nanopolish_NZ_CP016007.1           nanopolish                 20
# 927     nanopolish_NZ_CP013483.1           nanopolish                 20
# 928        nanopolish_CP010116.1           nanopolish                 20
# 929        nanopolish_CP010226.1           nanopolish                 20
# 930        nanopolish_CP010170.1           nanopolish                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 0               31054.0    0.490190      0.671789
# 1               22573.0    0.356316      0.394351
# 2               25630.0    0.404571      0.470119
# 3               23017.0    0.363325      0.410538
# 4               17542.0    0.276902      0.314518
# ..                  ...         ...           ...
# 926             10122.0    0.996750      0.995815
# 927             10093.0    0.993895      0.995047
# 928              9847.0    0.969670      0.970044
# 929              9982.0    0.982964      0.984003
# 930             10108.0    0.995372      0.996356
#
# [931 rows x 6 columns]

# %% [markdown]
# # Restricting to core genes

# %%
df_illumina_core_genes = df_illumina[df_illumina.NUMBER_OF_SAMPLES >= 16]
df_illumina_core_genes
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 686  pandora_illumina_withdenovo  pandora with denovo                 16
# 687           snippy_NC_011993.1               snippy                 16
# 688           snippy_NC_022648.1               snippy                 16
# 689            snippy_CP010121.1               snippy                 16
# 690         snippy_NZ_LM995446.1               snippy                 16
# ..                           ...                  ...                ...
# 926       samtools_NZ_CP016007.1             samtools                 20
# 927       samtools_NZ_CP013483.1             samtools                 20
# 928          samtools_CP010116.1             samtools                 20
# 929          samtools_CP010226.1             samtools                 20
# 930          samtools_CP010170.1             samtools                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 686             30983.0    0.897928      0.924857
# 687             33634.0    0.974757      0.975819
# 688             33435.0    0.968990      0.970195
# 689             33783.0    0.979075      0.979979
# 690             33028.0    0.957195      0.959243
# ..                  ...         ...           ...
# 926             10137.0    0.998227      0.997937
# 927             10123.0    0.996849      0.996470
# 928              9865.0    0.971443      0.971251
# 929             10013.0    0.986017      0.985810
# 930             10134.0    0.997932      0.997937
#
# [245 rows x 6 columns]

# %%
df_nanopore_core_genes = df_nanopore[df_nanopore.NUMBER_OF_SAMPLES >= 16]
df_nanopore_core_genes
# Out:
#            tool_long_description                 tool  NUMBER_OF_SAMPLES  \
# 686  pandora_nanopore_withdenovo  pandora with denovo                 16
# 687           medaka_NC_011993.1               medaka                 16
# 688           medaka_NC_022648.1               medaka                 16
# 689            medaka_CP010121.1               medaka                 16
# 690         medaka_NZ_LM995446.1               medaka                 16
# ..                           ...                  ...                ...
# 926     nanopolish_NZ_CP016007.1           nanopolish                 20
# 927     nanopolish_NZ_CP013483.1           nanopolish                 20
# 928        nanopolish_CP010116.1           nanopolish                 20
# 929        nanopolish_CP010226.1           nanopolish                 20
# 930        nanopolish_CP010170.1           nanopolish                 20
#
#      nb_of_found_PanVar  recall_PVR  recall_AvgAR
# 686             30752.0    0.891233      0.916472
# 687             34026.0    0.986118      0.981447
# 688             33856.0    0.981191      0.976094
# 689             34123.0    0.988929      0.984482
# 690             33373.0    0.967193      0.963241
# ..                  ...         ...           ...
# 926             10122.0    0.996750      0.995815
# 927             10093.0    0.993895      0.995047
# 928              9847.0    0.969670      0.970044
# 929              9982.0    0.982964      0.984003
# 930             10108.0    0.995372      0.996356
#
# [245 rows x 6 columns]

# %% [markdown]
# # Summing the number of found panvars

# %%
df_illumina_core_genes_panvars_summed = \
    df_illumina_core_genes.groupby(by=["tool_long_description", "tool"])\
    .agg({"nb_of_found_PanVar": np.sum})\
    .reset_index()
df_illumina_core_genes_panvars_summed
# Out:
#           tool_long_description                 tool  nb_of_found_PanVar
# 0   pandora_illumina_withdenovo  pandora with denovo            212545.0
# 1           samtools_CP010116.1             samtools            223347.0
# 2           samtools_CP010121.1             samtools            229188.0
# 3           samtools_CP010170.1             samtools            229184.0
# 4           samtools_CP010171.1             samtools            227638.0
# 5           samtools_CP010226.1             samtools            224917.0
# 6           samtools_CP010230.1             samtools            228538.0
# 7           samtools_CP018206.1             samtools            229818.0
# 8           samtools_CU928163.2             samtools            229653.0
# 9          samtools_NC_007779.1             samtools            228800.0
# 10         samtools_NC_010498.1             samtools            229670.0
# 11         samtools_NC_011742.1             samtools            229444.0
# 12         samtools_NC_011993.1             samtools            229364.0
# 13         samtools_NC_017646.1             samtools            229596.0
# 14         samtools_NC_022648.1             samtools            228883.0
# 15       samtools_NZ_CP008697.1             samtools            229504.0
# 16       samtools_NZ_CP009859.1             samtools            228142.0
# 17       samtools_NZ_CP011134.1             samtools            229496.0
# 18       samtools_NZ_CP013483.1             samtools            228192.0
# 19       samtools_NZ_CP015228.1             samtools            228131.0
# 20       samtools_NZ_CP016007.1             samtools            229458.0
# 21       samtools_NZ_CP018109.1             samtools            227194.0
# 22       samtools_NZ_HG941718.1             samtools            228862.0
# 23       samtools_NZ_LM995446.1             samtools            226936.0
# 24       samtools_NZ_LT632320.1             samtools            228831.0
# 25            snippy_CP010116.1               snippy            222871.0
# 26            snippy_CP010121.1               snippy            228723.0
# 27            snippy_CP010170.1               snippy            228673.0
# 28            snippy_CP010171.1               snippy            227038.0
# 29            snippy_CP010226.1               snippy            224421.0
# 30            snippy_CP010230.1               snippy            228071.0
# 31            snippy_CP018206.1               snippy            229259.0
# 32            snippy_CU928163.2               snippy            229164.0
# 33           snippy_NC_007779.1               snippy            228301.0
# 34           snippy_NC_010498.1               snippy            228994.0
# 35           snippy_NC_011742.1               snippy            228941.0
# 36           snippy_NC_011993.1               snippy            228847.0
# 37           snippy_NC_017646.1               snippy            228961.0
# 38           snippy_NC_022648.1               snippy            228359.0
# 39         snippy_NZ_CP008697.1               snippy            229057.0
# 40         snippy_NZ_CP009859.1               snippy            227558.0
# 41         snippy_NZ_CP011134.1               snippy            229001.0
# 42         snippy_NZ_CP013483.1               snippy            227683.0
# 43         snippy_NZ_CP015228.1               snippy            227548.0
# 44         snippy_NZ_CP016007.1               snippy            228930.0
# 45         snippy_NZ_CP018109.1               snippy            226671.0
# 46         snippy_NZ_HG941718.1               snippy            228351.0
# 47         snippy_NZ_LM995446.1               snippy            226437.0
# 48         snippy_NZ_LT632320.1               snippy            227400.0

# %%
df_nanopore_core_genes_panvars_summed = \
    df_nanopore_core_genes.groupby(by=["tool_long_description", "tool"])\
    .agg({"nb_of_found_PanVar": np.sum})\
    .reset_index()
df_nanopore_core_genes_panvars_summed
# Out:
#           tool_long_description                 tool  nb_of_found_PanVar
# 0             medaka_CP010116.1               medaka            223971.0
# 1             medaka_CP010121.1               medaka            229946.0
# 2             medaka_CP010170.1               medaka            229966.0
# 3             medaka_CP010171.1               medaka            228337.0
# 4             medaka_CP010226.1               medaka            225622.0
# 5             medaka_CP010230.1               medaka            229440.0
# 6             medaka_CP018206.1               medaka            230440.0
# 7             medaka_CU928163.2               medaka            230367.0
# 8            medaka_NC_007779.1               medaka            229484.0
# 9            medaka_NC_010498.1               medaka            230443.0
# 10           medaka_NC_011742.1               medaka            230175.0
# 11           medaka_NC_011993.1               medaka            230130.0
# 12           medaka_NC_017646.1               medaka            230336.0
# 13           medaka_NC_022648.1               medaka            229655.0
# 14         medaka_NZ_CP008697.1               medaka            230163.0
# 15         medaka_NZ_CP009859.1               medaka            228776.0
# 16         medaka_NZ_CP011134.1               medaka            230198.0
# 17         medaka_NZ_CP013483.1               medaka            228896.0
# 18         medaka_NZ_CP015228.1               medaka            229079.0
# 19         medaka_NZ_CP016007.1               medaka            230217.0
# 20         medaka_NZ_CP018109.1               medaka            227972.0
# 21         medaka_NZ_HG941718.1               medaka            229648.0
# 22         medaka_NZ_LM995446.1               medaka            227631.0
# 23         medaka_NZ_LT632320.1               medaka            229628.0
# 24        nanopolish_CP010116.1           nanopolish            222884.0
# 25        nanopolish_CP010121.1           nanopolish            228696.0
# 26        nanopolish_CP010170.1           nanopolish            228786.0
# 27        nanopolish_CP010171.1           nanopolish            227211.0
# 28        nanopolish_CP010226.1           nanopolish            224540.0
# 29        nanopolish_CP010230.1           nanopolish            228170.0
# 30        nanopolish_CP018206.1           nanopolish            229338.0
# 31        nanopolish_CU928163.2           nanopolish            229178.0
# 32       nanopolish_NC_007779.1           nanopolish            228383.0
# 33       nanopolish_NC_010498.1           nanopolish            229252.0
# 34       nanopolish_NC_011742.1           nanopolish            228977.0
# 35       nanopolish_NC_011993.1           nanopolish            228955.0
# 36       nanopolish_NC_017646.1           nanopolish            229086.0
# 37       nanopolish_NC_022648.1           nanopolish            228433.0
# 38     nanopolish_NZ_CP008697.1           nanopolish            229061.0
# 39     nanopolish_NZ_CP009859.1           nanopolish            227691.0
# 40     nanopolish_NZ_CP011134.1           nanopolish            229062.0
# 41     nanopolish_NZ_CP013483.1           nanopolish            227772.0
# 42     nanopolish_NZ_CP015228.1           nanopolish            227675.0
# 43     nanopolish_NZ_CP016007.1           nanopolish            229037.0
# 44     nanopolish_NZ_CP018109.1           nanopolish            226789.0
# 45     nanopolish_NZ_HG941718.1           nanopolish            228429.0
# 46     nanopolish_NZ_LM995446.1           nanopolish            226556.0
# 47     nanopolish_NZ_LT632320.1           nanopolish            228362.0
# 48  pandora_nanopore_withdenovo  pandora with denovo            211663.0

# %% [markdown]
# # Select the best values for each tool

# %%
df_illumina_best_values = \
    df_illumina_core_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).first()\
    .reset_index()
df_illumina_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar
# 0  pandora with denovo  pandora_illumina_withdenovo            212545.0
# 1             samtools          samtools_CP018206.1            229818.0
# 2               snippy            snippy_CP018206.1            229259.0

# %%
df_nanopore_best_values = \
    df_nanopore_core_genes_panvars_summed.sort_values(by=["nb_of_found_PanVar"], ascending=False).\
    groupby(by=["tool"]).first()\
    .reset_index()
df_nanopore_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar
# 0               medaka           medaka_NC_010498.1            230443.0
# 1           nanopolish        nanopolish_CP018206.1            229338.0
# 2  pandora with denovo  pandora_nanopore_withdenovo            211663.0

# %% [markdown]
# # Get how many panvars we have in total in core genes, to be able to compute the recall

# %%
pangenome_variations_per_nb_of_samples = pd.read_csv("../../pandora1_paper_analysis_output_20_way/technology_independent_analysis/pangenome_variants_vs_samples/pangenome_variations_per_nb_of_samples.csv")
pangenome_variations_per_nb_of_samples
# Out:
#           PVID  NUMBER_OF_SAMPLES
# 0            0                  2
# 1            1                  4
# 2            2                  2
# 3            3                 20
# 4            4                 19
# ...        ...                ...
# 618300  681407                  2
# 618301  681408                  2
# 618302  681409                  2
# 618303  681410                  2
# 618304  681411                  2
#
# [618305 rows x 2 columns]

# %%
pangenome_variations_per_nb_of_samples_in_core_genes = pangenome_variations_per_nb_of_samples[pangenome_variations_per_nb_of_samples.NUMBER_OF_SAMPLES <= 5]
pangenome_variations_per_nb_of_samples_in_core_genes
# Out:
#           PVID  NUMBER_OF_SAMPLES
# 0            0                  2
# 1            1                  4
# 2            2                  2
# 10          10                  2
# 12          12                  2
# ...        ...                ...
# 618300  681407                  2
# 618301  681408                  2
# 618302  681409                  2
# 618303  681410                  2
# 618304  681411                  2
#
# [160197 rows x 2 columns]

# %%
number_of_panvars_in_core_genes = len(pangenome_variations_per_nb_of_samples_in_core_genes)
display(number_of_panvars_in_core_genes)
# Out:
# 160197

# %% [markdown]
# # Compute recall

# %%
df_illumina_best_values["recall"] = df_illumina_best_values["nb_of_found_PanVar"] / number_of_panvars_in_core_genes
df_illumina_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar  \
# 0  pandora with denovo  pandora_illumina_withdenovo            212545.0
# 1             samtools          samtools_CP018206.1            229818.0
# 2               snippy            snippy_CP018206.1            229259.0
#
#      recall
# 0  1.326773
# 1  1.434596
# 2  1.431107

# %%
df_nanopore_best_values["recall"] = df_nanopore_best_values["nb_of_found_PanVar"] / number_of_panvars_in_core_genes
df_nanopore_best_values
# Out:
#                   tool        tool_long_description  nb_of_found_PanVar  \
# 0               medaka           medaka_NC_010498.1            230443.0
# 1           nanopolish        nanopolish_CP018206.1            229338.0
# 2  pandora with denovo  pandora_nanopore_withdenovo            211663.0
#
#      recall
# 0  1.438498
# 1  1.431600
# 2  1.321267

# %% [markdown]
# # Create report

# %%
def extract_value(df, queried_tool, column):
    return df[df.tool==queried_tool][column].to_list()[0]

from collections import defaultdict
tech_to_tool_to_measure = defaultdict(lambda: defaultdict(lambda: defaultdict(float)))

for measure in ["nb_of_found_PanVar", "recall"]:
    for tool in ["pandora with denovo", "samtools", "snippy"]:
        tech_to_tool_to_measure["illumina"][tool][measure] = extract_value(df_illumina_best_values, tool, measure)
    for tool in ["pandora with denovo", "medaka", "nanopolish"]:
        tech_to_tool_to_measure["nanopore"][tool][measure] = extract_value(df_nanopore_best_values, tool, measure)

tech_to_tool_to_measure
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'illumina': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pandora with denovo': defaultdict(float,
#                                       {'nb_of_found_PanVar': 212545.0,
#                                        'recall': 1.3267726611609456}),
#                           'samtools': defaultdict(float,
#                                       {'nb_of_found_PanVar': 229818.0,
#                                        'recall': 1.4345961534860203}),
#                           'snippy': defaultdict(float,
#                                       {'nb_of_found_PanVar': 229259.0,
#                                        'recall': 1.431106699875778})}),
#              'nanopore': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pandora with denovo': defaultdict(float,
#                                       {'nb_of_found_PanVar': 211663.0,
#                                        'recall': 1.3212669400800265}),
#                           'medaka': defaultdict(float,
#                                       {'nb_of_found_PanVar': 230443.0,
#                                        'recall': 1.438497599830209}),
#                           'nanopolish': defaultdict(float,
#                                       {'nb_of_found_PanVar': 229337.99999999997,
#                                        'recall': 1.4315998426936831})})})

# %%
print("For illumina:")
for tool in ["samtools", "snippy"]:
    print(f"Pandora identified {int(tech_to_tool_to_measure['illumina'][tool]['nb_of_found_PanVar'] - tech_to_tool_to_measure['illumina']['pandora with denovo']['nb_of_found_PanVar'])} less pan vars than {tool}")
    print(f"Pandora had a recall {round((tech_to_tool_to_measure['illumina'][tool]['recall'] - tech_to_tool_to_measure['illumina']['pandora with denovo']['recall'])*100, 1)}% lower than {tool}")

print("For nanopore:")
for tool in ["medaka", "nanopolish"]:
    print(f"Pandora identified {int(tech_to_tool_to_measure['nanopore'][tool]['nb_of_found_PanVar'] - tech_to_tool_to_measure['nanopore']['pandora with denovo']['nb_of_found_PanVar'])} less pan vars than {tool}")
    print(f"Pandora had a recall {round((tech_to_tool_to_measure['nanopore'][tool]['recall'] - tech_to_tool_to_measure['nanopore']['pandora with denovo']['recall'])*100, 1)}% lower than {tool}")
# Out:
# For illumina:
# Pandora identified 17273 less pan vars than samtools
# Pandora had a recall 10.8% lower than samtools
# Pandora identified 16714 less pan vars than snippy
# Pandora had a recall 10.4% lower than snippy
# For nanopore:
# Pandora identified 18780 less pan vars than medaka
# Pandora had a recall 11.7% lower than medaka
# Pandora identified 17674 less pan vars than nanopolish
# Pandora had a recall 11.0% lower than nanopolish
